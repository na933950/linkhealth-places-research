# %%
import pandas as pd

# %%
clean_zcta = lambda x: ((5 - x.astype(str).str.len()).apply(lambda y: y * "0") + x.astype(str))

# %%
design_matrix = pd.read_csv("../census_data/design_matrix_before_data_engineering.csv")
outcome_matrix = pd.read_csv("../outcome_matrix.csv")
outcome_matrix["ZCTA"] = clean_zcta(outcome_matrix["ZCTA"])
design_matrix["ZCTA"] = clean_zcta(design_matrix["ZCTA"])
merged_matrix = outcome_matrix.merge(design_matrix, on="ZCTA")
merged_matrix = merged_matrix[merged_matrix["Estimate Computers And Internet Use Total Households With A Broadband Internet Subscription As a Percent of Estimate Computers And Internet Use Total Households"] != 1]
Y = merged_matrix[["ZCTA", 
                   "Diagnosed diabetes among adults aged >=18 years",
                   "Mental health not good for >=14 days among adults aged >=18 years",
                   "Stroke among adults aged >=18 years"
                  ]]
X = merged_matrix.drop(columns=["Diagnosed diabetes among adults aged >=18 years",
                   "Mental health not good for >=14 days among adults aged >=18 years",
                   "Stroke among adults aged >=18 years"])
X.set_index("ZCTA", inplace=True)
Y.set_index("ZCTA", inplace=True)

# %%
Y_renamed = Y.rename(columns={"Diagnosed diabetes among adults aged >=18 years":"Individuals Age 18+ with Diagnosed Diabetes (%)",
                  "Mental health not good for >=14 days among adults aged >=18 years": "Individuals Age 18+ with Mental Health not Good for 14+ Days (%)",
                  "Stroke among adults aged >=18 years": "Individuals Age 18+ who Experienced Stroke (%)"}
        )
Y_renamed
# Out:
#        Individuals Age 18+ with Diagnosed Diabetes (%)  \
# ZCTA
# 01001                                            0.101
# 01002                                            0.068
# 01005                                            0.083
# 01007                                            0.071
# 01008                                            0.096
# ...                                                ...
# 99921                                            0.100
# 99922                                            0.131
# 99925                                            0.127
# 99926                                            0.138
# 99929                                            0.109
#
#        Individuals Age 18+ with Mental Health not Good for 14+ Days (%)  \
# ZCTA
# 01001                                              0.163
# 01002                                              0.202
# 01005                                              0.162
# ...

# %%
X_renamed = (
    X.rename(
        columns={
                    "Estimate Computers And Internet Use Total Households With A Broadband Internet Subscription As a Percent of Estimate Computers And Internet Use Total Households":"Households with Broadband Internet Access (%)",
                    "Estimate Computers And Internet Use Total Households With A Computer As a Percent of Estimate Computers And Internet Use Total Households":"Households with a Computer (%)",
                    "Estimate Disability Status Of The Civilian Noninstitutionalized Population 18 To 64 Years With A Disability As a Percent of Estimate Disability Status Of The Civilian Noninstitutionalized Population 18 To 64 Years":"Individuals in the Noninstitutionalized Population Between Age 18 and 64 with a Disability (%)",
                    "Estimate Disability Status Of The Civilian Noninstitutionalized Population Total Civilian Noninstitutionalized Population With A Disability As a Percent of Estimate Disability Status Of The Civilian Noninstitutionalized Population Total Civilian Noninstitutionalized Population":"Individuals in the Noninstitutionalized Population with a Disability (%)",
                    "Estimate Disability Status Of The Civilian Noninstitutionalized Population Under 18 Years With A Disability As a Percent of Estimate Disability Status Of The Civilian Noninstitutionalized Population Under 18 Years":"Individuals in the Noninstitutionalized Population Under Age 18 with a Disability (%)",
                    "Estimate Educational Attainment Population 25 Years And Over 9Th To 12Th Grade, No Diploma As a Percent of Estimate Educational Attainment Population 25 Years And Over":"Individuals Age 25 and Older with 9th - 12th Grade, no Diploma as Highest Level of Educational Attainment (%)",
                    "Estimate Educational Attainment Population 25 Years And Over Associate'S Degree As a Percent of Estimate Educational Attainment Population 25 Years And Over":"Individuals Age 25 and Older with an Associates Degree as Highest Level of Educational Attainment (%)",
                    "Estimate Educational Attainment Population 25 Years And Over Bachelor'S Degree As a Percent of Estimate Educational Attainment Population 25 Years And Over":"Individuals Age 25 and Older with a Bachelor's Degree as Highest Level of Educational Attainment (%)",
                    "Estimate Educational Attainment Population 25 Years And Over High School Graduate (Includes Equivalency) As a Percent of Estimate Educational Attainment Population 25 Years And Over":"Individuals Age 25 and Older with a High School Diploma (or Equivalent) as Highest Level of Educational Attainment (%)",
                    "Estimate Educational Attainment Population 25 Years And Over Less Than 9Th Grade As a Percent of Estimate Educational Attainment Population 25 Years And Over":"Individuals Age 25 and Older with less than 9th Grade as Highest Level of Educational Attainment (%)",
                    "Estimate Educational Attainment Population 25 Years And Over Some College, No Degree As a Percent of Estimate Educational Attainment Population 25 Years And Over":"Individuals Age 25 and Older with Some College as Highest Level of Educational Attainment (%)",
                    "Estimate Health Insurance Coverage Civilian Noninstitutionalized Population 19 To 64 Years As a Percent of Estimate Health Insurance Coverage Civilian Noninstitutionalized Population":"Individuals in the Noninstitutionalized Population Between Age 19 and 64 with Health Insurance Coverage (%)",
                    "Estimate Health Insurance Coverage Civilian Noninstitutionalized Population 19 To 64 Years In Labor Force Unemployed As a Percent of Estimate Health Insurance Coverage Civilian Noninstitutionalized Population":"Individuals in the Noninstitutionalized Population Between Age 19 and 64 with Health Insurance Coverage who are Unemployed (%)",
                    "Estimate Health Insurance Coverage Civilian Noninstitutionalized Population Under 19 Years As a Percent of Estimate Health Insurance Coverage Civilian Noninstitutionalized Population":"Individuals in the Noninstitutionalized Population Under Age 19 with Health Insurance Coverage (%)",
                    "Estimate Health Insurance Coverage Civilian Noninstitutionalized Population Under 19 Years No Health Insurance Coverage As a Percent of Estimate Health Insurance Coverage Civilian Noninstitutionalized Population":"Individuals in the Noninstitutionalized Population Under Age 19 without Health Insurance Coverage (%)",
                    "Estimate Health Insurance Coverage Civilian Noninstitutionalized Population With Health Insurance Coverage With Private Health Insurance As a Percent of Estimate Health Insurance Coverage Civilian Noninstitutionalized Population":"Individuals with Health Insurance Coverage in the Noninstitutionalized Population with Private Health Insurance (%)",
                    "Estimate Health Insurance Coverage Civilian Noninstitutionalized Population With Health Insurance Coverage With Public Coverage As a Percent of Estimate Health Insurance Coverage Civilian Noninstitutionalized Population":"Individuals with Health Insurance Coverage in the Noninstitutionalized Population with Public Health Insurance (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Hispanic Or Latino (Of Any Race) As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Drop_Col",
                    "Estimate Hispanic Or Latino And Race Total Population Hispanic Or Latino (Of Any Race) Cuban As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Hispanic or Latino Individuals who are Cuban (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Hispanic Or Latino (Of Any Race) Mexican As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Hispanic or Latino Individuals who are Mexican (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Hispanic Or Latino (Of Any Race) Puerto Rican As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Hispanic or Latino Individuals who are Puerto Rican (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino American Indian And Alaska Native Alone As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are Native American Alone (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Asian Alone As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are Asian Alone (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Black Or African American Alone As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are Black or African American Alone (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Native Hawaiian And Other Pacific Islander Alone As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are Native Hawaiian and Other Pacific Islander Alone (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Some Other Race Alone As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are some Other Race (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Two Or More Races As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are Multiracial (%)",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Two Or More Races Two Races Excluding Some Other Race, And Three Or More Races As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Drop_Col_2",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino Two Or More Races Two Races Including Some Other Race As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Drop_Col_3",
                    "Estimate Hispanic Or Latino And Race Total Population Not Hispanic Or Latino White Alone As a Percent of Estimate Hispanic Or Latino And Race Total Population":"Non-Hispanic or Latino Individuals who are White Alone (%)",
                    "Estimate Households By Type Total Households Cohabiting Couple Household As a Percent of Estimate Households By Type Total Households":"Households which have a Cohabiting Couple (%)",
                    "Estimate Households By Type Total Households Households With One Or More People 65 Years And Over As a Percent of Estimate Households By Type Total Households":"Households with one or more Individuals Age 65 and Older (%)",
                    "Estimate Households By Type Total Households Households With One Or More People Under 18 Years As a Percent of Estimate Households By Type Total Households":"Households with one or more Individuals Under Age 18 (%)",
                    "Estimate Households By Type Total Households Married-Couple Household As a Percent of Estimate Households By Type Total Households":"Households with Married-Couples (%)",
                    "Estimate Households By Type Total Households Married-Couple Household With Children Of The Householder Under 18 Years As a Percent of Estimate Households By Type Total Households":"Drop_Col_4",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Median Earnings For Workers (Dollars)":"Median Earnings for Workers",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Per Capita Income (Dollars)":"Income Per Capita",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $10,000 To $14,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $10,000 to $14,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $100,000 To $149,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $100,000 to $149,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $15,000 To $24,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $15,000 to $24,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $150,000 To $199,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $150,000 to $199,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $25,000 To $34,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $25,000 to $34,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $35,000 To $49,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $35,000 to $49,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $50,000 To $74,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between 510,000 to $74,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households $75,000 To $99,999 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Between $75,000 to $99,999 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households Less Than $10,000 As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Total Income and Benefits Less Than $10,000 (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households Mean Household Income (Dollars)":"Mean Household Income",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households Median Household Income (Dollars)":"Median Household Income",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households With Cash Public Assistance Income As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Cash Public Assistance Income (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households With Earnings As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Drop_Col_5",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households With Food Stamp/Snap Benefits In The Past 12 Months As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Food Stamp/SNAP Benefits in the Past 12 Months (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households With Retirement Income As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Retirement Income (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households With Social Security As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Social Security (%)",
                    "Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households With Supplemental Security Income As a Percent of Estimate Income And Benefits (In 2021 Inflation-Adjusted Dollars) Total Households":"Households with Supplemental Security Income (%)",
                    "Estimate Language Spoken At Home Population 5 Years And Over English Only As a Percent of Estimate Language Spoken At Home Population 5 Years And Over":"Individuals Age 5 Years and Older who Only Speak English at Home",
                    "Estimate Language Spoken At Home Population 5 Years And Over Language Other Than English As a Percent of Estimate Language Spoken At Home Population 5 Years And Over":"Individuals Age 5 Years and Older who Speak a Non-English Language at Home",
                    "Estimate Percentage Of Families And People Whose Income In The Past 12 Months Is Below The Poverty Level All Families Married Couple Families As a Percent of Estimate Percentage Of Families And People Whose Income In The Past 12 Months Is Below The Poverty Level All Families":"Families who are Married Couple Families and Below the Poverty Level as a Percent of All Families Below the Poverty Level (%)",
                    "Estimate Race Total Population One Race American Indian And Alaska Native As a Percent of Estimate Race Total Population":"Drop_Col_6",
                    "Estimate Race Total Population One Race American Indian And Alaska Native Cherokee Tribal Grouping As a Percent of Estimate Race Total Population":"Individuals who are Cherokee Only (%)",
                    "Estimate Race Total Population One Race American Indian And Alaska Native Chippewa Tribal Grouping As a Percent of Estimate Race Total Population":"Individuals who are Chippewa Only (%)",
                    "Estimate Race Total Population One Race American Indian And Alaska Native Navajo Tribal Grouping As a Percent of Estimate Race Total Population":"Individuals who are Navajo Only (%)",
                    "Estimate Race Total Population One Race American Indian And Alaska Native Sioux Tribal Grouping As a Percent of Estimate Race Total Population":"Individuals who are Sioux Only (%)",
                    "Estimate Race Total Population One Race As a Percent of Estimate Race Total Population":"Individuals who are Monoracial (%)",
                    "Estimate Race Total Population One Race Asian As a Percent of Estimate Race Total Population":"Individuals who are Asian Only (%)",
                    "Estimate Race Total Population One Race Asian Asian Indian As a Percent of Estimate Race Total Population":"Individuals who are Indian Only (%)",
                    "Estimate Race Total Population One Race Asian Chinese As a Percent of Estimate Race Total Population":"Individuals who are Chinese Only (%)",
                    "Estimate Race Total Population One Race Asian Filipino As a Percent of Estimate Race Total Population":"Individuals who are Filipino Only (%)",
                    "Estimate Race Total Population One Race Asian Japanese As a Percent of Estimate Race Total Population":"Individuals who are Japanese Only (%)",
                    "Estimate Race Total Population One Race Asian Korean As a Percent of Estimate Race Total Population":"Individuals who are Korean Only (%)",
                    "Estimate Race Total Population One Race Asian Vietnamese As a Percent of Estimate Race Total Population":"Individuals who are Vietnamese Only (%)",
                    "Estimate Race Total Population One Race Black Or African American As a Percent of Estimate Race Total Population":"Individuals who are Black or African American Only (%)",
                    "Estimate Race Total Population One Race Native Hawaiian And Other Pacific Islander As a Percent of Estimate Race Total Population":"Individuals who are Native Hawaiian and Other Pacific Islander Only (%)",
                    "Estimate Race Total Population One Race Native Hawaiian And Other Pacific Islander Chamorro As a Percent of Estimate Race Total Population":"Individuals who are Chamorro Only (%)",
                    "Estimate Race Total Population One Race Native Hawaiian And Other Pacific Islander Native Hawaiian As a Percent of Estimate Race Total Population":"Individuals who are Native Hawaiian Only (%)",
                    "Estimate Race Total Population One Race Native Hawaiian And Other Pacific Islander Samoan As a Percent of Estimate Race Total Population":"Individuals who are Samoan Only (%)",
                    "Estimate Race Total Population One Race Some Other Race As a Percent of Estimate Race Total Population":"Individuals who are Some Other Race Only (%)",
                    "Estimate Race Total Population One Race White As a Percent of Estimate Race Total Population":"Individuals who are White Only (%)",
                    "Estimate Race Total Population Two Or More Races As a Percent of Estimate Race Total Population":"Individuals who are Biracial (%)",
                    "Estimate Race Total Population Two Or More Races Black Or African American And American Indian And Alaska Native As a Percent of Estimate Race Total Population":"Drop_Col_7",
                    "Estimate Race Total Population Two Or More Races White And American Indian And Alaska Native As a Percent of Estimate Race Total Population":"Drop_Col_8",
                    "Estimate Race Total Population Two Or More Races White And Asian As a Percent of Estimate Race Total Population":"Individuals who are White and Asian (%)",
                    "Estimate Race Total Population Two Or More Races White And Black Or African American As a Percent of Estimate Race Total Population":"Individuals who are White and Black or African American (%)",
                    "Estimate Sex And Age Total Population 10 To 14 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 10 to 14 (%)",
                    "Estimate Sex And Age Total Population 15 To 19 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 15 to 19 (%)",
                    "Estimate Sex And Age Total Population 20 To 24 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 20 to 24 (%)",
                    "Estimate Sex And Age Total Population 25 To 34 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 25 to 34 (%)",
                    "Estimate Sex And Age Total Population 35 To 44 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 34 to 44 (%)",
                    "Estimate Sex And Age Total Population 45 To 54 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 45 to 54 (%)",
                    "Estimate Sex And Age Total Population 5 To 9 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 5 to 9 (%)",
                    "Estimate Sex And Age Total Population 55 To 59 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 55 to 59 (%)",
                    "Estimate Sex And Age Total Population 60 To 64 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 60 to 64 (%)",
                    "Estimate Sex And Age Total Population 65 To 74 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 65 to 74 (%)",
                    "Estimate Sex And Age Total Population 75 To 84 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Aged 75 to 85 (%)",
                    "Estimate Sex And Age Total Population Male As a Percent of Estimate Sex And Age Total Population":"Individuals who are Male by Birth (%)",
                    "Estimate Sex And Age Total Population Median Age (Years)":"Median Age",
                    "Estimate Sex And Age Total Population Under 5 Years As a Percent of Estimate Sex And Age Total Population":"Individuals Under 5 Years Old (%)",
                    "Estimate Veteran Status Civilian Population 18 Years And Over Civilian Veterans As a Percent of Estimate Veteran Status Civilian Population 18 Years And Over":"Individuals Aged 18 Years and Older who are Civilian Veterans (%)",
                    "Estimate Households By Type Total Households Average Family Size":"Average Family Size",
                    "Estimate Households By Type Total Households Average Household Size":"Average Household Size"
                }
        )
)
X_renamed
# Out:
#        Households with Broadband Internet Access (%)  \
# ZCTA
# 01001                                          0.851
# 01002                                          0.929
# 01005                                          0.918
# 01007                                          0.943
# 01008                                          0.775
# ...                                              ...
# 99921                                          0.734
# 99922                                          0.587
# 99925                                          0.571
# 99926                                          0.691
# 99929                                          0.776
#
#        Households with a Computer (%)  \
# ZCTA
# 01001                           0.899
# 01002                           0.970
# 01005                           0.930
# 01007                           0.968
# 01008                           0.941
# ...                               ...
# ...

# %%
X
# Out:
#        Estimate Computers And Internet Use Total Households With A Broadband Internet Subscription As a Percent of Estimate Computers And Internet Use Total Households  \
# ZCTA
# 01001                                              0.851
# 01002                                              0.929
# 01005                                              0.918
# 01007                                              0.943
# 01008                                              0.775
# ...                                                  ...
# 99921                                              0.734
# 99922                                              0.587
# 99925                                              0.571
# 99926                                              0.691
# 99929                                              0.776
#
#        Estimate Computers And Internet Use Total Households With A Computer As a Percent of Estimate Computers And Internet Use Total Households  \
# ZCTA
# ...

# %%
#Split the set
from sklearn.model_selection import train_test_split

X_train_val, X_test, Y_train_val, Y_test = train_test_split(X_renamed, Y_renamed, test_size=0.2, random_state=1894)

# %% [raw]
# X_train_val.to_csv("./X_train_val.csv")
# X_test.to_csv("./X_test.csv")
# Y_train_val.to_csv("./Y_train_val.csv")
# Y_test.to_csv("./Y_test.csv")
