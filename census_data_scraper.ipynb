# %% [markdown]
# <h1>Creating an Automatic Census Data Scraper by State</h1>
# <h2><b>IMPORTANT:</b><br><span style="color:red;">This product uses the Census Bureau Data API but is not endorsed or certified by the Census Bureau.</span></h2>

# %% [markdown]
# <h2>Setting up the Census Bureau API</h2>

# %%
import pandas as pd
import numpy as np
import requests
import csv
import warnings
warnings.simplefilter('ignore') #Turn off warnings

# %%
base_url = "https://api.census.gov/data/2021/acs/acs5/profile?get="
api_key = "672276f2a0ad053d60f8bb0848cad8a290a29427"
zcta_url = "&for=zip%20code%20tabulation%20area:" # need to include a 0 at the end when using the ZCTA range

# %%
variable_table_url = f'https://api.census.gov/data/2021/acs/acs5/profile/groups/DP02.html'
v_table = pd.read_html(variable_table_url) # reading all available variables from API for the ACS5
variable_df = pd.DataFrame(v_table[0])
variable_df['Label'].replace({"!!": " ", ":": ""}, regex=True, inplace=True)
variable_df
# Out:
#                 Name                                              Label  \
# 0         DP02_0001E       Estimate HOUSEHOLDS BY TYPE Total households
# 1        DP02_0001EA  Annotation of Estimate HOUSEHOLDS BY TYPE Tota...
# 2         DP02_0001M  Margin of Error HOUSEHOLDS BY TYPE Total house...
# 3        DP02_0001MA  Annotation of Margin of Error HOUSEHOLDS BY TY...
# 4        DP02_0001PE        Percent HOUSEHOLDS BY TYPE Total households
# ...              ...                                                ...
# 1228     DP02_0154PE  Percent COMPUTERS AND INTERNET USE Total house...
# 1229    DP02_0154PEA  Annotation of Percent COMPUTERS AND INTERNET U...
# 1230     DP02_0154PM  Percent Margin of Error COMPUTERS AND INTERNET...
# 1231    DP02_0154PMA  Annotation of Percent Margin of Error COMPUTER...
# 1232  1232 variables                                     1232 variables
#
#                                                 Concept        Required  \
# 0     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 1     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 2     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 3     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 4     SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# ...                                                 ...             ...
# 1228  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 1229  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 1230  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 1231  SELECTED SOCIAL CHARACTERISTICS IN THE UNITED ...  predicate-only
# 1232                                     1232 variables  1232 variables
#
#           Attributes           Limit  Predicate Type           Group  \
# 0                NaN               0             int            DP02
# 1                NaN               0          string            DP02
# 2                NaN               0             int            DP02
# 3                NaN               0          string            DP02
# 4                NaN               0             int            DP02
# ...              ...             ...             ...             ...
# 1228             NaN               0           float            DP02
# 1229             NaN               0          string            DP02
# 1230             NaN               0           float            DP02
# 1231             NaN               0          string            DP02
# 1232  1232 variables  1232 variables  1232 variables  1232 variables
#
#           Unnamed: 8
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1228             NaN
# 1229             NaN
# 1230             NaN
# 1231             NaN
# 1232  1232 variables
#
# [1233 rows x 9 columns]

# %%
feature_list = list(variable_df["Label"])

with open('feature_list_social.txt', 'w', encoding='utf-8') as file:
    for feature in feature_list:
        if feature.startswith("Estimate"):
            file.write(feature + '\n\n')

# %% [markdown]
# <h2>Getting list for Demographic Features</h2>

# %%
variable_table_url = f'https://api.census.gov/data/2021/acs/acs5/profile/groups/DP03.html'
v_table = pd.read_html(variable_table_url) # reading all available variables from API for the ACS5
variable_df = pd.DataFrame(v_table[0])
variable_df['Label'].replace({"!!": " ", ":": ""}, regex=True, inplace=True)
variable_df
# Out:
#                 Name                                              Label  \
# 0         DP03_0001E  Estimate EMPLOYMENT STATUS Population 16 years...
# 1        DP03_0001EA  Annotation of Estimate EMPLOYMENT STATUS Popul...
# 2         DP03_0001M  Margin of Error EMPLOYMENT STATUS Population 1...
# 3        DP03_0001MA  Annotation of Margin of Error EMPLOYMENT STATU...
# 4        DP03_0001PE  Percent EMPLOYMENT STATUS Population 16 years ...
# ...              ...                                                ...
# 1092     DP03_0137PE  Percent PERCENTAGE OF FAMILIES AND PEOPLE WHOS...
# 1093    DP03_0137PEA  Annotation of Percent PERCENTAGE OF FAMILIES A...
# 1094     DP03_0137PM  Percent Margin of Error PERCENTAGE OF FAMILIES...
# 1095    DP03_0137PMA  Annotation of Percent Margin of Error PERCENTA...
# 1096  1096 variables                                     1096 variables
#
#                                 Concept        Required      Attributes  \
# 0     SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 1     SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 2     SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 3     SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 4     SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# ...                                 ...             ...             ...
# 1092  SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 1093  SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 1094  SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 1095  SELECTED ECONOMIC CHARACTERISTICS  predicate-only             NaN
# 1096                     1096 variables  1096 variables  1096 variables
#
#                Limit  Predicate Type           Group      Unnamed: 8
# 0                  0             int            DP03             NaN
# 1                  0          string            DP03             NaN
# 2                  0             int            DP03             NaN
# 3                  0          string            DP03             NaN
# 4                  0             int            DP03             NaN
# ...              ...             ...             ...             ...
# 1092               0           float            DP03             NaN
# 1093               0          string            DP03             NaN
# 1094               0           float            DP03             NaN
# 1095               0          string            DP03             NaN
# 1096  1096 variables  1096 variables  1096 variables  1096 variables
#
# [1097 rows x 9 columns]

# %%
feature_list = list(variable_df["Label"])

with open('feature_list_economic.txt', 'w', encoding='utf-8') as file:
    for feature in feature_list:
        if feature.startswith("Estimate"):
            file.write(feature + '\n\n')

# %% [markdown]
# <h2>Getting Demographic Features</h2>

# %%
variable_table_url = f'https://api.census.gov/data/2021/acs/acs5/profile/groups/DP05.html'
v_table = pd.read_html(variable_table_url) # reading all available variables from API for the ACS5
variable_df = pd.DataFrame(v_table[0])
variable_df['Label'].replace({"!!": " ", ":": ""}, regex=True, inplace=True)
variable_df
# Out:
#               Name                                              Label  \
# 0       DP05_0001E              Estimate SEX AND AGE Total population
# 1      DP05_0001EA  Annotation of Estimate SEX AND AGE Total popul...
# 2       DP05_0001M       Margin of Error SEX AND AGE Total population
# 3      DP05_0001MA  Annotation of Margin of Error SEX AND AGE Tota...
# 4      DP05_0001PE               Percent SEX AND AGE Total population
# ..             ...                                                ...
# 708    DP05_0089PE  Percent CITIZEN, VOTING AGE POPULATION Citizen...
# 709   DP05_0089PEA  Annotation of Percent CITIZEN, VOTING AGE POPU...
# 710    DP05_0089PM  Percent Margin of Error CITIZEN, VOTING AGE PO...
# 711   DP05_0089PMA  Annotation of Percent Margin of Error CITIZEN,...
# 712  712 variables                                      712 variables
#
#                                    Concept        Required     Attributes  \
# 0    ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 1    ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 2    ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 3    ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 4    ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# ..                                     ...             ...            ...
# 708  ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 709  ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 710  ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 711  ACS DEMOGRAPHIC AND HOUSING ESTIMATES  predicate-only            NaN
# 712                          712 variables   712 variables  712 variables
#
#              Limit Predicate Type          Group     Unnamed: 8
# 0                0            int           DP05            NaN
# 1                0         string           DP05            NaN
# 2                0            int           DP05            NaN
# 3                0         string           DP05            NaN
# 4                0            int           DP05            NaN
# ..             ...            ...            ...            ...
# 708              0          float           DP05            NaN
# 709              0         string           DP05            NaN
# 710              0          float           DP05            NaN
# 711              0         string           DP05            NaN
# 712  712 variables  712 variables  712 variables  712 variables
#
# [713 rows x 9 columns]

# %%
feature_list = list(variable_df["Label"])

with open('feature_list_demographic.txt', 'w', encoding='utf-8') as file:
    for feature in feature_list:
        if feature.startswith("Estimate"):
            file.write(feature + '\n\n')

# %%
variable_table = variable_df['Name'][0:1232]
variable_table = variable_table[~variable_table.str.endswith('A')] # want to remove values ending in A
variable_table.reset_index(drop = True, inplace = True)
variable_table
# Out:
# 0       DP02_0001E
# 1       DP02_0001M
# 2      DP02_0001PE
# 3      DP02_0001PM
# 4       DP02_0002E
#           ...
# 611    DP02_0153PM
# 612     DP02_0154E
# 613     DP02_0154M
# 614    DP02_0154PE
# 615    DP02_0154PM
# Name: Name, Length: 616, dtype: object

# %%
test = ','.join(variable_table[0:48])
test_all_vars_url = f"{base_url}{test}{zcta_url}01001&key={api_key}"
response = requests.get(test_all_vars_url)

# %%
labels = response.json()[0][:-1]
values = response.json()[1:][0][:-1]
test_dict = {labels[i]: values[i] for i in range(len(values))}

test_df = variable_df[~variable_df["Name"].str.endswith("A")]
test_df.reset_index(drop = True, inplace = True)
test_labels = test_df["Label"][0:192]
test_dict2 = {test_labels[i]: values[i] for i in range(len(values))}

test_df = pd.DataFrame(np.array(values).reshape(-1,4)).rename(columns = {0: "Estimate", 
                                                               1: "Margin of Error", 
                                                               2: "Percent", 
                                                               3: "Percent Margin of Error"})
test_df
# Out:
#    Estimate Margin of Error Percent Percent Margin of Error
# 0      6791             345    6791              -888888888
# 1      2959             265    43.6                     4.1
# 2       874             173    12.9                     2.6
# 3       726             232    10.7                     3.3
# 4       196             129     2.9                     1.9
# 5      1156             222    17.0                     3.2
# 6        48              55     0.7                     0.8
# 7       843             207    12.4                     3.0
# 8       367             146     5.4                     2.1
# 9      1950             314    28.7                     4.0
# 10      344             153     5.1                     2.2
# 11     1352             293    19.9                     3.9

# %%
test_labels = test_labels[0::4]
new_index = [test_labels[i][test_labels[i].find("BY TYPE")+8:] for i in range(0, len(test_labels), 4)]

test_df.index = new_index
test_df
# Out:
#                                                    Estimate Margin of Error  \
# Total households                                       6791             345
# Total households Married-couple household              2959             265
# Total households Married-couple household With ...      874             173
# Total households Cohabiting couple household            726             232
# Total households Cohabiting couple household Wi...      196             129
# Total households Male householder, no spouse/pa...     1156             222
# Total households Male householder, no spouse/pa...       48              55
# Total households Male householder, no spouse/pa...      843             207
# Total households Male householder, no spouse/pa...      367             146
# Total households Female householder, no spouse/...     1950             314
# Total households Female householder, no spouse/...      344             153
# Total households Female householder, no spouse/...     1352             293
#
#                                                    Percent  \
# Total households                                      6791
# Total households Married-couple household             43.6
# Total households Married-couple household With ...    12.9
# Total households Cohabiting couple household          10.7
# Total households Cohabiting couple household Wi...     2.9
# Total households Male householder, no spouse/pa...    17.0
# Total households Male householder, no spouse/pa...     0.7
# Total households Male householder, no spouse/pa...    12.4
# Total households Male householder, no spouse/pa...     5.4
# Total households Female householder, no spouse/...    28.7
# Total households Female householder, no spouse/...     5.1
# Total households Female householder, no spouse/...    19.9
#
#                                                    Percent Margin of Error
# Total households                                                -888888888
# Total households Married-couple household                              4.1
# Total households Married-couple household With ...                     2.6
# Total households Cohabiting couple household                           3.3
# Total households Cohabiting couple household Wi...                     1.9
# Total households Male householder, no spouse/pa...                     3.2
# Total households Male householder, no spouse/pa...                     0.8
# Total households Male householder, no spouse/pa...                     3.0
# Total households Male householder, no spouse/pa...                     2.1
# Total households Female householder, no spouse/...                     4.0
# Total households Female householder, no spouse/...                     2.2
# Total households Female householder, no spouse/...                     3.9

# %%
social_labels = variable_df["Label"][:1232:8].reset_index(drop=True).str.title()

# Getting labels for the Demographic Table
variable_table_url = f'https://api.census.gov/data/2021/acs/acs5/profile/groups/DP05.html'
v_table = pd.read_html(variable_table_url) # reading all available variables from API for the ACS5
variable_df = pd.DataFrame(v_table[0])
variable_df['Label'].replace({"!!": " ", ":": ""}, regex=True, inplace=True)

demographic_labels = variable_df["Label"][:712:8].reset_index(drop=True).str.title()

# %%
def get_social_df_url(url):
    response = requests.get(url)
    print(response.status_code) if response.status_code != 200 else False
    if response.status_code == 200:
        data = response.json()
        valid_data = np.array(data[1:][0][:-4:2]).reshape(-1,4)
        socs_df = pd.DataFrame(valid_data).rename(columns = {0: "Estimate", 
                                                             1: "Margin of Error", 
                                                             2: "Percent", 
                                                             3: "Percent Margin of Error"})

        # Need to add proper indices. 
        socs_df.index = social_labels
        # Need to replace "-888888888", need to do for rest of Annotation values.
        socs_df = test_df.replace("-888888888", "(X)")
    
        return socs_df
    else:
        return 0

# %% [markdown]
# <h2>Pulling ZCTA Per State to Allow Scraping by State</h2>

# %%
zcta_mapping_df = pd.read_excel("./ani_csv/ZIPCodetoZCTACrosswalk2021UDS.xlsx")
zcta_mapping_df
# Out:
#        ZIP_CODE      PO_NAME STATE                              ZIP_TYPE  \
# 0           501   Holtsville    NY  Post Office or large volume customer
# 1           544   Holtsville    NY  Post Office or large volume customer
# 2           601     Adjuntas    PR                         Zip Code Area
# 3           602       Aguada    PR                         Zip Code Area
# 4           603    Aguadilla    PR                         Zip Code Area
# ...         ...          ...   ...                                   ...
# 41086     99926   Metlakatla    AK                         Zip Code Area
# 41087     99927  Point Baker    AK                         Zip Code Area
# 41088     99928    Ward Cove    AK  Post Office or large volume customer
# 41089     99929     Wrangell    AK                         Zip Code Area
# 41090     99950    Ketchikan    AK                         Zip Code Area
#
#           ZCTA         zip_join_type
# 0      11742.0  Spatial join to ZCTA
# 1      11742.0  Spatial join to ZCTA
# 2        601.0      Zip matches ZCTA
# 3        602.0      Zip matches ZCTA
# 4        603.0      Zip matches ZCTA
# ...        ...                   ...
# 41086  99926.0      Zip matches ZCTA
# 41087  99927.0      Zip matches ZCTA
# 41088  99901.0  Spatial join to ZCTA
# 41089  99929.0      Zip matches ZCTA
# 41090  99921.0  Spatial join to ZCTA
#
# [41091 rows x 6 columns]

# %%
#Clean it so it is only ZCTA and State

zcta_to_state = zcta_mapping_df[["STATE", "ZCTA"]]
zcta_to_state = zcta_to_state[~zcta_to_state["ZCTA"].isna()]
zcta_to_state["ZCTA"] = zcta_to_state["ZCTA"].astype(int)
zcta_to_state
# Out:
#       STATE   ZCTA
# 0        NY  11742
# 1        NY  11742
# 2        PR    601
# 3        PR    602
# 4        PR    603
# ...     ...    ...
# 41086    AK  99926
# 41087    AK  99927
# 41088    AK  99901
# 41089    AK  99929
# 41090    AK  99921
#
# [41083 rows x 2 columns]

# %%
clean_zip = lambda zip: str(zip) if zip > 10000 else (f"0{zip}" if zip >= 1000 else f"00{zip}")
zcta_to_state['ZCTA'] = zcta_to_state['ZCTA'].map(clean_zip)
zcta_to_state
# Out:
#       STATE   ZCTA
# 0        NY  11742
# 1        NY  11742
# 2        PR  00601
# 3        PR  00602
# 4        PR  00603
# ...     ...    ...
# 41086    AK  99926
# 41087    AK  99927
# 41088    AK  99901
# 41089    AK  99929
# 41090    AK  99921
#
# [41083 rows x 2 columns]

# %% [markdown]
# <h2>Preparing State-Specific Scraping Function</h2>

# %%
import os

# %%
def get_social_df_state(abbrev):
    base_url = "https://api.census.gov/data/2021/acs/acs5/profile?get="
    api_key = "&key=672276f2a0ad053d60f8bb0848cad8a290a29427"
    group = "group(DP02)"
    zcta_url = "&for=zip%20code%20tabulation%20area:"

    ZCTA_Range = list(zcta_to_state[zcta_to_state["STATE"] == abbrev]["ZCTA"])
    
    try:
        os.mkdir("census_data")
    except:
        pass
    
    try:
        os.mkdir("./census_data/social_chars")
    except:
        pass
    
    try:
        os.mkdir(f"./census_data/social_chars/{abbrev}")
    except:
        pass

    for zcta in ZCTA_Range:
        url = f"{base_url}{group}{zcta_url}{zcta}{api_key}"
        new_social_df = get_social_df_url(url)
        if not isinstance(new_social_df, pd.DataFrame):
            continue
        else:
            try:
                new_social_df.to_csv(f"census_data/social_chars/{abbrev}/{zcta}.csv")
            except:
                pass

# %% [raw]
# get_social_df_state("MA")

# %%
len(list(zcta_to_state[zcta_to_state["STATE"] == "MA"]["ZCTA"]))
#It took 10 minutes, or around 600 seconds to scrape 681 data sets
#Texas has 1939 ZCTAs so it will take an estimated
# Out:
# 681

# %% [raw]
# get_social_df_state("TX")

# %%
# Getting labels for the Demographic Table
variable_table_url = f'https://api.census.gov/data/2021/acs/acs5/profile/groups/DP03.html'
v_table = pd.read_html(variable_table_url) # reading all available variables from API for the ACS5
variable_df = pd.DataFrame(v_table[0])
variable_df['Label'].replace({"!!": " ", ":": ""}, regex=True, inplace=True)

economic_labels = variable_df['Label'][:1089:8].reset_index(drop=True).str.title()
economic_labels
# Out:
# 0      Estimate Employment Status Population 16 Years...
# 1      Estimate Employment Status Population 16 Years...
# 2      Estimate Employment Status Population 16 Years...
# 3      Estimate Employment Status Population 16 Years...
# 4      Estimate Employment Status Population 16 Years...
#                              ...
# 132    Estimate Percentage Of Families And People Who...
# 133    Estimate Percentage Of Families And People Who...
# 134    Estimate Percentage Of Families And People Who...
# 135    Estimate Percentage Of Families And People Who...
# 136    Estimate Percentage Of Families And People Who...
# Name: Label, Length: 137, dtype: object

# %%
def get_economic_df_url(url):
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        valid_data = np.array(data[1][:-3:2]).reshape(-1,4)
        demo_df = pd.DataFrame(valid_data).rename(columns = {0: "Estimate", 
                                                             1: "Margin of Error", 
                                                             2: "Percent", 
                                                             3: "Percent Margin of Error"})

        # Need to add proper indices. 
        demo_df.index = economic_labels
        # Need to replace "-888888888", need to do for rest of Annotation values.
        demo_df = demo_df.replace("-888888888", "(X)")
    
        return demo_df
    else:
        return response.status_code

# %%
base_url = "https://api.census.gov/data/2021/acs/acs5/profile?get="
api_key = "&key=672276f2a0ad053d60f8bb0848cad8a290a29427"
group = "group(DP03)"
zcta_url = "&for=zip%20code%20tabulation%20area:"

# %%
test_url = f"{base_url}{group}{zcta_url}01002{api_key}"
get_economic_df_url(test_url)
# Out:
#                                                    Estimate Margin of Error  \
# Label
# Estimate Employment Status Population 16 Years ...    24110             717
# Estimate Employment Status Population 16 Years ...    15630            1029
# Estimate Employment Status Population 16 Years ...    15630            1029
# Estimate Employment Status Population 16 Years ...    14536             994
# Estimate Employment Status Population 16 Years ...     1094             385
# ...                                                     ...             ...
# Estimate Percentage Of Families And People Whos...      (X)             (X)
# Estimate Percentage Of Families And People Whos...      (X)             (X)
# Estimate Percentage Of Families And People Whos...      (X)             (X)
# Estimate Percentage Of Families And People Whos...      (X)             (X)
# Estimate Percentage Of Families And People Whos...      (X)             (X)
#
#                                                    Percent  \
# Label
# Estimate Employment Status Population 16 Years ...   24110
# Estimate Employment Status Population 16 Years ...    64.8
# Estimate Employment Status Population 16 Years ...    64.8
# Estimate Employment Status Population 16 Years ...    60.3
# Estimate Employment Status Population 16 Years ...     4.5
# ...                                                    ...
# Estimate Percentage Of Families And People Whos...    24.8
# Estimate Percentage Of Families And People Whos...    29.1
# Estimate Percentage Of Families And People Whos...     3.7
# Estimate Percentage Of Families And People Whos...     6.7
# Estimate Percentage Of Families And People Whos...    46.7
#
#                                                    Percent Margin of Error
# Label
# Estimate Employment Status Population 16 Years ...                     (X)
# Estimate Employment Status Population 16 Years ...                     3.4
# Estimate Employment Status Population 16 Years ...                     3.4
# Estimate Employment Status Population 16 Years ...                     3.5
# Estimate Employment Status Population 16 Years ...                     1.6
# ...                                                                    ...
# Estimate Percentage Of Families And People Whos...                     3.4
# Estimate Percentage Of Families And People Whos...                     4.0
# Estimate Percentage Of Families And People Whos...                     2.1
# Estimate Percentage Of Families And People Whos...                     2.6
# Estimate Percentage Of Families And People Whos...                     6.8
#
# [137 rows x 4 columns]

# %%
def get_economic_df_state(abbrev):
    base_url = "https://api.census.gov/data/2021/acs/acs5/profile?get="
    api_key = "&key=672276f2a0ad053d60f8bb0848cad8a290a29427"
    group = "group(DP03)"
    zcta_url = "&for=zip%20code%20tabulation%20area:"

    ZCTA_Range = list(zcta_to_state[zcta_to_state["STATE"] == abbrev]["ZCTA"])
    
    try:
        os.mkdir("census_data")
    except:
        pass
    
    try:
        os.mkdir("./census_data/economic_chars")
    except:
        pass
    
    try:
        os.mkdir(f"./census_data/economic_chars/{abbrev}")
    except:
        pass

    for zcta in ZCTA_Range:
        url = f"{base_url}{group}{zcta_url}{zcta}{api_key}"
        new_economic_df = get_economic_df_url(url)
        if not isinstance(new_economic_df, pd.DataFrame):
            print(f"Failed at zcta {zcta} - Error code {new_economic_df}")
            continue
        else:
            try:
                new_economic_df.to_csv(f"census_data/economic_chars/{abbrev}/{zcta}.csv")
            except:
                pass

# %%
get_economic_df_state("MA")
# Out:
# Failed at zcta 01086 - Error code 204
# Failed at zcta 01199 - Error code 204
# Failed at zcta 01467 - Error code 204
# Failed at zcta 02651 - Error code 204
# Failed at zcta 02669 - Error code 204

# %%
get_economic_df_state("TX")
# Out:
# Failed at zcta 75832 - Error code 204
# Failed at zcta 75978 - Error code 204
# Failed at zcta 76508 - Error code 204
# Failed at zcta 76949 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 77201 - Error code 204
# Failed at zcta 78060 - Error code 204
# Failed at zcta 78335 - Error code 204
# Failed at zcta 79105 - Error code 204
# Failed at zcta 79831 - Error code 204
# Failed at zcta 79942 - Error code 204
